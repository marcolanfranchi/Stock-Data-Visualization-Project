# %% [markdown]
# ![capm_formula_1.png](attachment:capm_formula_1.png)

# %% [markdown]
# Problem we are solving:
#
# We are testing the accuracy of the CAPM formula by using it to calculate the expected return on IBM and comparing this return to the historical return on IBM as well as the difference of the two returns for a set of dates.

# %% [markdown]
# Where the info is from:
#
#  - yahoo finance (Return on S&P 500 and Return on IBM)
#  - beta source (Beta)
#  - U.S. federal website (Risk Free Rates)

# %% [markdown]
# ![Excel%20Data.JPG](attachment:Excel%20Data.JPG)

# %% [markdown]
# Why it's interesting to us:

# %% [markdown]
# Design choice: [Walk through the data definition choices (i.e. why we chose them - compound and arbitrary sized) as well as walking through the analyze and helper functions)].

# %% [markdown]
# Most Challenging Part:
#
# - designing the (correct) helper functions
# - displaying the x-axis in a readable way

# %% [markdown]
# Future Work:
#
# - We could take this project topic a step further and look at multiple stocks across different industries and see if the capm is more accurate for stocks in certain industries
# - Apart from this, we could also look at how a company's attributes (i.e. sales growth, dividend payments etc.) is correlated with its overall stock performance
